# %% [markdown]
# Connecting to the bronze container to retrieve the raw data

# %%
dbutils.fs.ls("/mnt/bronze")
# Out:
# [FileInfo(path='dbfs:/mnt/bronze/customer.csv', name='customer.csv', size=65579, modificationTime=1714665014000),
#  FileInfo(path='dbfs:/mnt/bronze/products.csv', name='products.csv', size=144540, modificationTime=1714665027000),
#  FileInfo(path='dbfs:/mnt/bronze/stores.csv', name='stores.csv', size=904638, modificationTime=1714665041000)]

# %% [markdown]
# Checking for data in silver container

# %%
dbutils.fs.ls("/mnt/silver")
# Out:
# [FileInfo(path='dbfs:/mnt/silver/df_customer/', name='df_customer/', size=0, modificationTime=1714685212000),
#  FileInfo(path='dbfs:/mnt/silver/df_product/', name='df_product/', size=0, modificationTime=1714685219000),
#  FileInfo(path='dbfs:/mnt/silver/df_store/', name='df_store/', size=0, modificationTime=1714685221000)]

# %% [markdown]
# Assigning paths of customer, product, store tables

# %%
customers_path = '/mnt/bronze/customer.csv'
products_path = '/mnt/bronze/products.csv'
store_path = '/mnt/bronze/stores.csv'

# %% [markdown]
# Loading Data into DataFrame from CSV

# %%
df_customer = spark.read.format('csv').option('header', 'true').load(customers_path)
df_product = spark.read.format('csv').option('header', 'true').load(products_path)
df_store = spark.read.format('csv').option('header', 'true').load(store_path)

# %% [markdown]
# Understanding data in each table

# %%
display(df_customer.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Customer_ID</th><th>Customer_Name</th><th>Segment</th><th>Country</th><th>City</th><th>State</th><th>Postal_Code</th><th>Region</th><th>Age</th></tr></thead><tbody><tr><td>CG/12520</td><td>Claire Gute</td><td>Consumer</td><td>United States</td><td>Henderson</td><td>Kentucky</td><td>42420</td><td>South</td><td>42</td></tr><tr><td>DV/13045</td><td>Darrin Van Huff</td><td>Corporate</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90036</td><td>West</td><td>47</td></tr><tr><td>SO/20335</td><td>Sean O'Donnell</td><td>Consumer</td><td>United States</td><td>Fort Lauderdale</td><td>Florida</td><td>33311</td><td>South</td><td>19</td></tr><tr><td>BH/11710</td><td>Brosina Hoffman</td><td>Consumer</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90032</td><td>West</td><td>39</td></tr><tr><td>AA/10480</td><td>Andrew Allen</td><td>Consumer</td><td>United States</td><td>Concord</td><td>North Carolina</td><td>28027</td><td>South</td><td>31</td></tr></tbody></table></div>

# %%
df_customer.count()
# Out:
# 793

# %% [markdown]
# Checking summary of age column in customer table

# %%
df_customer.select("Age").describe().show()
# Out:
# +-------+------------------+
# |summary|               Age|
# +-------+------------------+
# |  count|               793|
# |   mean|33.746532156368225|
# | stddev| 8.628123278990762|
# |    min|                19|
# |    max|                48|
# +-------+------------------+

# %%
display(df_product.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product_ID</th><th>Category</th><th>Sub_Category</th><th>Product_Name</th></tr></thead><tbody><tr><td>FUR-BO-10001798</td><td>Furniture</td><td>Bookcases</td><td>Bush Somerset Collection Bookcase</td></tr><tr><td>FUR-CH-10000454</td><td>Furniture</td><td>Chairs</td><td>Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back</td></tr><tr><td>OFF-LA-10000240</td><td>Office Supplies</td><td>Labels</td><td>Self-Adhesive Address Labels for Typewriters by Universal</td></tr><tr><td>FUR-TA-10000577</td><td>Furniture</td><td>Tables</td><td>Bretford CR4500 Series Slim Rectangular Table</td></tr><tr><td>OFF-ST-10000760</td><td>Office Supplies</td><td>Storage</td><td>Eldon Fold 'N Roll Cart System</td></tr></tbody></table></div>

# %%
df_product.count()
# Out:
# 1861

# %%
display(df_store.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Row_ID</th><th>Order_ID</th><th>Order_Date</th><th>Ship_Date</th><th>Ship_Mode</th><th>Customer_ID</th><th>Product_ID</th><th>Sales</th><th>Discount</th></tr></thead><tbody><tr><td>1</td><td>CA-2017-152156</td><td>11/8/2017</td><td>11/11/2017</td><td>Second Class</td><td>CG/12520</td><td>FUR-BO-10001798</td><td>3929400</td><td>0.02</td></tr><tr><td>2</td><td>CA-2017-152156</td><td>11/8/2017</td><td>11/11/2017</td><td>Second Class</td><td>CG/12520</td><td>FUR-CH-10000454</td><td>10979100</td><td>0.01</td></tr><tr><td>3</td><td>CA-2017-138688</td><td>6/12/2017</td><td>6/16/2017</td><td>Second Class</td><td>DV/13045</td><td>OFF-LA-10000240</td><td>219300</td><td>0.01</td></tr><tr><td>4</td><td>US-2016-108966</td><td>10/11/2016</td><td>10/18/2016</td><td>Standard Class</td><td>SO/20335</td><td>FUR-TA-10000577</td><td>14363662.5</td><td>0.02</td></tr><tr><td>5</td><td>US-2016-108966</td><td>10/11/2016</td><td>10/18/2016</td><td>Standard Class</td><td>SO/20335</td><td>OFF-ST-10000760</td><td>335520</td><td>0.03</td></tr></tbody></table></div>

# %%
df_store.count()
# Out:
# 9800

# %% [markdown]
# Checking for null values in each dataframe

# %%
from pyspark.sql.functions import count, when, isnull, col

dfs = [df_customer, df_product, df_store]
df_names = ["df_customer", "df_product", "df_store"]

for i, df in enumerate(dfs, start=1):
    print(f"Null values in {df_names[i-1]}:")
    df.select([count(when(isnull(col), col)).alias(col) for col in df.columns]).show()
# Out:
# Null values in df_customer:
# +-----------+-------------+-------+-------+----+-----+-----------+------+---+
# |Customer_ID|Customer_Name|Segment|Country|City|State|Postal_Code|Region|Age|
# +-----------+-------------+-------+-------+----+-----+-----------+------+---+
# |          0|            0|      0|      0|   0|    0|          0|     0|  0|
# +-----------+-------------+-------+-------+----+-----+-----------+------+---+
#
# Null values in df_product:
# +----------+--------+------------+------------+
# |Product_ID|Category|Sub_Category|Product_Name|
# +----------+--------+------------+------------+
# |         0|       0|           0|           0|
# +----------+--------+------------+------------+
#
# Null values in df_store:
# +------+--------+----------+---------+---------+-----------+----------+-----+--------+
# |Row_ID|Order_ID|Order_Date|Ship_Date|Ship_Mode|Customer_ID|Product_ID|Sales|Discount|
# +------+--------+----------+---------+---------+-----------+----------+-----+--------+
# |     0|       0|         0|        0|        0|          0|         0|   30|       0|
# +------+--------+----------+---------+---------+-----------+----------+-----+--------+

# %% [markdown]
# As we can see, we found 30 records in the store dataframe with null values

# %%
df_store.where(col("Sales").isNull()).show()
# Out:
# +------+--------------+----------+----------+--------------+-----------+---------------+-----+--------+
# |Row_ID|      Order_ID|Order_Date| Ship_Date|     Ship_Mode|Customer_ID|     Product_ID|Sales|Discount|
# +------+--------------+----------+----------+--------------+-----------+---------------+-----+--------+
# |    76|US-2018-118038| 12/9/2018|12/11/2018|   First Class|   KB/16600|OFF-BI-10004182| NULL|    0.01|
# |   977|US-2018-100209|  7/9/2018| 7/15/2018|Standard Class|   TD/20995|OFF-BI-10002012| NULL|    0.01|
# |   988|CA-2016-146829| 3/10/2016| 3/10/2016|      Same Day|   TS/21340|OFF-BI-10004022| NULL|    0.01|
# |  1113|US-2017-110156|11/19/2017|11/24/2017|Standard Class|   EH/13945|OFF-BI-10002609| NULL|    0.03|
# |  1333|CA-2015-122567| 2/16/2015| 2/21/2015|Standard Class|   MN/17935|OFF-BI-10002012| NULL|    0.03|
# |  1686|CA-2018-149489| 4/24/2018| 4/27/2018|   First Class|   DK/12835|OFF-BI-10002813| NULL|    0.02|
# |  2107|US-2015-152723| 9/26/2015| 9/26/2015|      Same Day|   HG/14965|OFF-BI-10003460| NULL|    0.01|
# |  2347|CA-2017-159373| 3/13/2017| 3/18/2017|Standard Class|   LT/17110|OFF-BI-10004141| NULL|    0.01|
# |  2428|CA-2017-169922| 6/11/2017| 6/17/2017|Standard Class|   MZ/17515|OFF-BI-10003784| NULL|    0.01|
# |  2606|CA-2015-112718|12/16/2015|12/21/2015|Standard Class|   KN/16450|OFF-BI-10000591| NULL|    0.03|
# |  2762|CA-2018-126536|10/12/2018|10/14/2018|   First Class|   NK/18490|TEC-AC-10003709| NULL|    0.01|
# |  3326|CA-2015-165309|11/11/2015|11/15/2015|Standard Class|   KD/16270|OFF-BI-10001267| NULL|    0.01|
# |  3767|CA-2017-163153| 3/21/2017| 3/25/2017|Standard Class|   DM/12955|OFF-AR-10001868| NULL|    0.02|
# |  4102|US-2018-102288| 6/19/2018| 6/23/2018|Standard Class|   ZC/21910|OFF-AP-10002906| NULL|    0.03|
# |  4712|CA-2015-112403| 3/31/2015| 3/31/2015|      Same Day|   JO/15280|OFF-BI-10003529| NULL|    0.01|
# |  4875|CA-2018-164042| 5/23/2018| 5/27/2018|Standard Class|   KL/16645|OFF-BI-10001922| NULL|    0.01|
# |  4934|CA-2016-106978| 9/28/2016| 10/4/2016|Standard Class|   ZC/21910|OFF-BI-10002012| NULL|    0.02|
# |  5207|CA-2016-102016| 9/12/2016| 9/18/2016|Standard Class|   TM/21010|OFF-FA-10000490| NULL|    0.03|
# |  5857|CA-2016-112214|  8/5/2016| 8/11/2016|Standard Class|   AH/10690|OFF-BI-10002982| NULL|    0.02|
# |  6090|US-2018-162068|12/28/2018|12/31/2018|  Second Class|   PC/18745|OFF-BI-10002813| NULL|    0.02|
# +------+--------------+----------+----------+--------------+-----------+---------------+-----+--------+
# only showing top 20 rows

# %% [markdown]
# Checking null values count in store dataframe

# %%
df_store.where(col("Sales").isNull()).count()
# Out:
# 30

# %% [markdown]
# Dropping records with null values

# %%
df_store = df_store.dropna(subset=["Sales"])
df_store.show()
# Out:
# +------+--------------+----------+----------+--------------+-----------+---------------+----------+--------+
# |Row_ID|      Order_ID|Order_Date| Ship_Date|     Ship_Mode|Customer_ID|     Product_ID|     Sales|Discount|
# +------+--------------+----------+----------+--------------+-----------+---------------+----------+--------+
# |     1|CA-2017-152156| 11/8/2017|11/11/2017|  Second Class|   CG/12520|FUR-BO-10001798|   3929400|    0.02|
# |     2|CA-2017-152156| 11/8/2017|11/11/2017|  Second Class|   CG/12520|FUR-CH-10000454|  10979100|    0.01|
# |     3|CA-2017-138688| 6/12/2017| 6/16/2017|  Second Class|   DV/13045|OFF-LA-10000240|    219300|    0.01|
# |     4|US-2016-108966|10/11/2016|10/18/2016|Standard Class|   SO/20335|FUR-TA-10000577|14363662.5|    0.02|
# |     5|US-2016-108966|10/11/2016|10/18/2016|Standard Class|   SO/20335|OFF-ST-10000760|    335520|    0.03|
# |     6|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|FUR-FU-10001487|    732900|    0.02|
# |     7|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|OFF-AR-10002833|    109200|    0.02|
# |     8|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|TEC-PH-10002275|  13607280|    0.02|
# |     9|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|OFF-BI-10003910|    277560|    0.02|
# |    10|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|OFF-AP-10002892|   1723500|    0.01|
# |    11|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|FUR-TA-10001539|  25592760|    0.01|
# |    12|CA-2015-115812|  6/9/2015| 6/14/2015|Standard Class|   BH/11710|TEC-PH-10002033|  13671360|    0.03|
# |    13|CA-2018-114412| 4/15/2018| 4/20/2018|Standard Class|   AA/10480|OFF-PA-10002365|    233280|    0.02|
# |    14|CA-2017-161389| 12/5/2017|12/10/2017|Standard Class|   IM/15070|OFF-BI-10003656|   6119640|    0.02|
# |    15|US-2016-118983|11/22/2016|11/26/2016|Standard Class|   HP/14815|OFF-AP-10002311|   1032150|    0.02|
# |    16|US-2016-118983|11/22/2016|11/26/2016|Standard Class|   HP/14815|OFF-BI-10000756|     38160|    0.03|
# |    17|CA-2015-105893|11/11/2015|11/18/2015|Standard Class|   PK/19075|OFF-ST-10004186|   9988200|    0.02|
# |    18|CA-2015-167164| 5/13/2015| 5/15/2015|  Second Class|   AG/10270|OFF-ST-10000107|    832500|    0.01|
# |    19|CA-2015-143336| 8/27/2015|  9/1/2015|  Second Class|   ZD/21925|OFF-AR-10003056|    128400|    0.01|
# |    20|CA-2015-143336| 8/27/2015|  9/1/2015|  Second Class|   ZD/21925|TEC-PH-10001949|   3202200|    0.03|
# +------+--------------+----------+----------+--------------+-----------+---------------+----------+--------+
# only showing top 20 rows

# %% [markdown]
# Checking null values count in store dataframe after removing records with null values

# %%
df_store.where(col("Sales").isNull()).count()
# Out:
# 0

# %% [markdown]
# Checking for duplicate records in each dataframe

# %%
dfs = [df_customer, df_product, df_store]
df_names = ["df_customer", "df_product", "df_store"]

for i, df in enumerate(dfs, start=1):
    original_count = df.count()
    no_duplicates_count = df.dropDuplicates().count()
    
    if no_duplicates_count < original_count:
        print(f"Duplicates found in {df_names[i-1]}.")
    else:
        print(f"No duplicates found in {df_names[i-1]}.")
# Out:
# No duplicates found in df_customer.
# No duplicates found in df_product.
# No duplicates found in df_store.

# %% [markdown]
# Checking data type of each column in customer

# %%
df_customer.printSchema()
# Out:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- Customer_Name: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal_Code: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Age: string (nullable = true)

# %% [markdown]
# Changing age column datatype

# %%
df_customer = df_customer.withColumn("Age", col("Age").cast("integer"))
df_customer.printSchema()
# Out:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- Customer_Name: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal_Code: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Age: integer (nullable = true)

# %% [markdown]
# Checking data type of each column in Store

# %%
df_store.printSchema()
# Out:
# root
#  |-- Row_ID: string (nullable = true)
#  |-- Order_ID: string (nullable = true)
#  |-- Order_Date: string (nullable = true)
#  |-- Ship_Date: string (nullable = true)
#  |-- Ship_Mode: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Product_ID: string (nullable = true)
#  |-- Sales: string (nullable = true)
#  |-- Discount: string (nullable = true)

# %% [markdown]
# Changing Sales, Discount columns datatypes

# %%
from pyspark.sql.functions import col

for col_name in ['Sales', 'Discount']:
    df_store = df_store.withColumn(col_name, col(col_name).cast("double"))

df_store.printSchema()
# Out:
# root
#  |-- Row_ID: string (nullable = true)
#  |-- Order_ID: string (nullable = true)
#  |-- Order_Date: string (nullable = true)
#  |-- Ship_Date: string (nullable = true)
#  |-- Ship_Mode: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Product_ID: string (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- Discount: double (nullable = true)

# %% [markdown]
# Removing Row_ID column from Store table

# %%
df_store = df_store.drop('Row_ID')
display(df_store.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Order_ID</th><th>